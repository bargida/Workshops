# %% [markdown]
# <a href="https://colab.research.google.com/github/bargida/Workshops/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
data_full = pd.read_csv("kc_house_data.csv")

# %%
data = data_full.sample(n=21000, random_state=279)

# %%
data_full.shape
# Out:
# (21613, 21)

# %%
empty_rows = data[data.isnull().any(axis=1)]

# %%
num_empty_rows = len(empty_rows)
print(f"Number of empty rows: {num_empty_rows}")
# Out:
# Number of empty rows: 0

# %%
def correlation_heatmap(df1):
  _, ax = plt.subplots(figsize = (15,10))
  colormap = sns.diverging_palette(220, 10, as_cmap = True)
  sns.heatmap(df1.corr(), annot = True, cmap = colormap)

# %%
selected_data = data[['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement', 'sqft_living15',
'sqft_lot15']]
correlation_heatmap(selected_data)

# %%
sns.regplot(x='sqft_living', y='price', data=data)
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
sns.stripplot(x='grade', y='price', data=data, size=5)
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
data=data[data[ 'bedrooms'] < 12]

# %%
c=['bedrooms','bathrooms','sqft_living','sqft_above','grade']
df= data[c]

# %%
df=pd.get_dummies(df,columns=[ 'grade'], drop_first=True)

# %%
y=data['price']

# %%
from re import X
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=42)

# %%
x_train.head()
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_above  grade_3  grade_4  \
# 6633          4       3.50         3780        3110    False    False
# 1891          4       3.00         2580        2580    False    False
# 16594         4       2.25         3750        2440    False    False
# 19478         4       1.00         1430         730    False    False
# 20513         3       2.50         1790        1790    False    False
#
#        grade_5  grade_6  grade_7  grade_8  grade_9  grade_10  grade_11  \
# 6633     False    False    False    False     True     False     False
# 1891     False    False    False     True    False     False     False
# 16594    False    False    False     True    False     False     False
# 19478    False     True    False    False    False     False     False
# 20513    False    False    False     True    False     False     False
#
#        grade_12  grade_13
# 6633      False     False
# 1891      False     False
# 16594     False     False
# 19478     False     False
# 20513     False     False

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics
print('Coefficients:\n ', reg.coef_)
print('Mean Squared Error ', metrics.mean_squared_error(y_test,
                                                        reg.predict(x_test)))
print('R-square ', reg.score(x_test,y_test))
# Out:
# Coefficients:
#   [-2.35566803e+04 -3.53438265e+03  2.46735225e+02 -1.01131629e+02
#  -9.87726859e+04  5.53369463e+04  6.54098297e+04  8.53749192e+04
#   1.11303324e+05  1.82445820e+05  3.29433559e+05  5.18774552e+05
#   8.30230446e+05  1.35871436e+06  2.33784672e+06]
# Mean Squared Error  56164203196.80409
# R-square  0.5835881463286074

# %%
fig, axarr=plt.subplots(3, figsize=(12,40))
sns.boxplot(y='floors', x='price', data=data,width=0.8,
  orient='h', showmeans=True, fliersize=3, ax=axarr[0])
sns.boxplot(y='view', x='price', data=data,width=0.8,
  orient='h', showmeans=True, fliersize=3, ax=axarr[1])
sns.boxplot(y='condition', x='price', data=data,width=0.8,
  orient='h', showmeans=True, fliersize=3, ax=axarr[2])
plt.show()

# %%
import folium
from folium.plugins import HeatMap

# %%
maxpr = data.loc[data['price'].idxmax()]

# %%
def generateBaseMap(default_location=[47.5112, -122.257],default_zoom_start=9.4):
  base_map = folium.Map(location=default_location, control_scale=True,
                        zoom_start=default_zoom_start)
  return base_map
df_copy=data.copy()

# %%
df_copy['count'] = 1
basemap = generateBaseMap()
folium.TileLayer('cartodbpositron').add_to(basemap)
s=folium.FeatureGroup(name='icon').add_to(basemap)
folium.Marker([maxpr['lat'], maxpr['long']],
              popup = 'Highest Price: $'+str(format(maxpr['price'],'.0f')),
              icon=folium.Icon(color='green')).add_to(s)
HeatMap(data=df_copy[['lat', 'long', 'count']].groupby(['lat', 'long']).sum().reset_index(),
        radius=8,max_zoom=13,name='Heat Map').add_to(basemap)
folium.LayerControl(collapsed=False).add_to(basemap)
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8487209d4c0c514d48ba09eae2530004 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8487209d4c0c514d48ba09eae2530004&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8487209d4c0c514d48ba09eae2530004 = L.map(
#                 &quot;map_8487209d4c0c514d48ba09eae2530004&quot;,
#                 {
#                     center: [47.5112, -122.257],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8487209d4c0c514d48ba09eae2530004);
#
#
#
#
#
#             var tile_layer_9979e3e7d2b5a5a4e7d4208f0d715e8e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9979e3e7d2b5a5a4e7d4208f0d715e8e.addTo(map_8487209d4c0c514d48ba09eae2530004);
#
#
#             var tile_layer_8d56c75f2aa0ec8537b90cf17fb1d670 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8d56c75f2aa0ec8537b90cf17fb1d670.addTo(map_8487209d4c0c514d48ba09eae2530004);
#
#
#             var feature_group_89273186249f15f42e10879bb50e8365 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_8f98e680dd2f5b1891a6669f7da4e98b = L.marker(
#                 [47.6298, -122.323],
#                 {}
#             ).addTo(feature_group_89273186249f15f42e10879bb50e8365);
#
#
#             var icon_21dda3bde25b1e96dfb1732e89141d63 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8f98e680dd2f5b1891a6669f7da4e98b.setIcon(icon_21dda3bde25b1e96dfb1732e89141d63);
#
#
#         var popup_a8216574ef7c3ec82608ee9b88bd7fc2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37785642bff88a574fbadc375302de46 = $(`&lt;div id=&quot;html_37785642bff88a574fbadc375302de46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Highest Price: $7700000&lt;/div&gt;`)[0];
#                 popup_a8216574ef7c3ec82608ee9b88bd7fc2.setContent(html_37785642bff88a574fbadc375302de46);
#
#
#
#         marker_8f98e680dd2f5b1891a6669f7da4e98b.bindPopup(popup_a8216574ef7c3ec82608ee9b88bd7fc2)
#         ;
#
#
#
#
#             feature_group_89273186249f15f42e10879bb50e8365.addTo(map_8487209d4c0c514d48ba09eae2530004);
#
#
#             var heat_map_bc8bc31d153e45dfbe4a8220ab7bff63 = L.heatLayer(
#                 [[47.1559, -121.646, 1.0], [47.1593, -121.957, 1.0], [47.1622, -121.971, 1.0], [47.1647, -121.973, 1.0], [47.1764, -122.026, 1.0], [47.1775, -122.022, 1.0], [47.1776, -122.011, 1.0], [47.1776, -121.944, 1.0], [47.1795, -122.036, 1.0], [47.1803, -121.974, 1.0], [47.1808, -122.023, 1.0], [47.184, -121.959, 1.0], [47.1853, -122.017, 1.0], [47.1879, -121.973, 1.0], [47.1895, -122.015, 1.0], [47.1896, -122.014, 1.0], [47.1896, -122.013, 1.0], [47.19, -122.016, 1.0], [47.19, -122.013, 1.0], [47.1903, -122.013, 1.0], [47.1913, -122.015, 1.0], [47.1913, -122.012, 1.0], [47.1923, -122.014, 1.0], [47.1924, -121.988, 1.0], [47.1927, -122.015, 1.0], [47.1927, -122.011, 1.0], [47.1927, -122.01, 1.0], [47.1928, -122.01, 1.0], [47.1932, -122.008, 1.0], [47.1934, -121.977, 1.0], [47.1936, -121.981, 1.0], [47.1937, -121.99, 1.0], [47.1937, -121.98, 1.0], [47.1937, -121.977, 1.0], [47.1938, -121.981, 1.0], [47.194, -121.981, 1.0], [47.1941, -122.038, 1.0], [47.1941, -121.979, 1.0], [47.1942, -121.99, 1.0], [47.1942, -121.977, 1.0], [47.1943, -121.991, 1.0], [47.1944, -122.013, 1.0], [47.1944, -121.974, 1.0], [47.1946, -122.003, 1.0], [47.1946, -122.0, 1.0], [47.1947, -122.008, 1.0], [47.1947, -121.989, 1.0], [47.1948, -121.999, 1.0], [47.1948, -121.975, 2.0], [47.1948, -121.974, 1.0], [47.1949, -122.01, 1.0], [47.1949, -121.989, 1.0], [47.1949, -121.982, 1.0], [47.1951, -122.01, 1.0], [47.1951, -122.001, 1.0], [47.1952, -121.986, 1.0], [47.1952, -121.976, 1.0], [47.1955, -121.999, 1.0], [47.1955, -121.991, 1.0

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
from sklearn import metrics
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('R-squared:', reg.score(x_test, y_test))
# Out:
# Mean Squared Error: 56164203196.80409
# R-squared: 0.5835881463286074

# %%
from sklearn import metrics
print('Coefficients:\n ', reg.coef_)
print('Mean Squared Error ', metrics.mean_squared_error(y_test, reg.predict(x_test)))
print('R-square ', reg.score(x_test,y_test))
# Out:
# Coefficients:
#   [-2.35566803e+04 -3.53438265e+03  2.46735225e+02 -1.01131629e+02
#  -9.87726859e+04  5.53369463e+04  6.54098297e+04  8.53749192e+04
#   1.11303324e+05  1.82445820e+05  3.29433559e+05  5.18774552e+05
#   8.30230446e+05  1.35871436e+06  2.33784672e+06]
# Mean Squared Error  56164203196.80409
# R-square  0.5835881463286074
